# %% [markdown]
# `Black Friday Sales Data Analysis`

# %% [markdown]
# The dataset contains over 537,000 rows and 12 columns.
# Columns: User ID, Product ID, Gender, Age, Occupation, City Category, Stay in Current City Years, Marital Status, Product Categories, and Purchase amount.

# %% [markdown]
# ### Walkthrough

# %% [markdown]
# Load the dataset, inspect its structure, and understand the contents.

# %%
import pandas as pd

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 537572    False       False   False  False       False          False
# 537573    False       False   False  False       False          False
# 537574    False       False   False  False       False          False
# 537575    False       False   False  False       False          False
# 537576    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
# instead of removing whole null rows, just removing the only columns having null values. As it won't affect the dataset more.

del df['Product_Category_2']
del df['Product_Category_3']

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ### Analyzing Columns

# %% [markdown]
# Dive deeper into each column to understand their distributions and relevance. and extract meaningful information from individual columns

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['Occupation'].nunique()
# Out:
# 21

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Purchase'].sum()
# Out:
# 5017668378

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
for column in df.columns:
    print(column, ":", df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# ### Analyzing Gender

# %% [markdown]
# Analyze the gender distribution of the customers and examine if there are any purchasing trends based on gender.

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data = pd.DataFrame({'Ratio':[len(df[df["Gender"] == 'M']), len(df[df["Gender"] == 'F'])]},
                    index = ["Male", "Female"])

# %%
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot.pie(y = 'Ratio', figsize = (6,6), autopct="%.2f")
# Out:
# <Axes: ylabel='Ratio'>

# %%
# same but using groupby function

gen = df.groupby("Gender").size()

# %%
gen
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
# gen = gen.rename(index={'F': 'Female', 'M': 'Male'})
gen.plot(kind='bar', 
         figsize=(6,6),
         color=['pink','skyblue'],
         ylabel="Count",
         rot=0
         )
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %%
df.groupby('Gender')['Purchase'].sum()
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind = 'pie', autopct = "%0.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### Analyzing Age & Marital Status

# %% [markdown]
#  Investigate how age groups and marital status affect purchasing behavior.

# %% [markdown]
# ### Age

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby('Age').size().plot(kind="bar",figsize=(10,6), title="Purchase Distribution by Age", rot=0)
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
lst = []
for i in df["Age"].unique():
    lst.append([i, df[df['Age']==i]['Product_ID'].nunique()])

data = pd.DataFrame(lst, columns=['Age', 'Products'])

# %%
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot.bar(x='Age', rot=0, title='Product distribution among different age groups')
# Out:
# <Axes: title={'center': 'Product distribution among different age groups'}, xlabel='Age'>

# %%
age_purchase = df.groupby('Age')['Purchase'].sum()

# %%
age_purchase
# Out:
# Age
# 0-17      132659006
# 18-25     901669280
# 26-35    1999749106
# 36-45    1010649565
# 46-50     413418223
# 51-55     361908356
# 55+       197614842
# Name: Purchase, dtype: int64

# %%
age_purchase.plot(kind='bar', rot=0,title = 'Amount Spend by Age')
# Out:
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %%
# average spend by the age groups
avg_purchase = df.groupby('Age')['Purchase'].mean()

# %%
avg_purchase
# Out:
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64

# %%
avg_purchase.plot.bar(title='Average spend', rot=0)
# Out:
# <Axes: title={'center': 'Average spend'}, xlabel='Age'>

# %%
avg_purchase.plot.pie(autopct='%.1f',title='Average spend', rot=0)
# Out:
# <Axes: title={'center': 'Average spend'}, ylabel='Purchase'>

# %% [markdown]
# ### Marital Status

# %%
df.groupby('Marital_Status').size()
# Out:
# Marital_Status
# 0    317817
# 1    219760
# dtype: int64

# %% [markdown]
# ### Multi Column Analysis

# %% [markdown]
# Combine multiple columns to analyze more complex relationships and derive insights from combinations of factors.

# %%
df.groupby('Age').size().plot(kind = 'bar', figsize = (12, 6), title = 'Purchase Distribution by Age', rot=0)
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
import seaborn as sns

# %% [markdown]
# seaborn.countplot is a function within the Seaborn Python library used to visualize the counts of observations in each category of a categorical variable. It is essentially a specialized bar plot where the height of each bar represents the number of occurrences of a particular category.

# %%
sns.set_theme(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Age", hue='Gender', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = "Gender", hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = "Marital_Status", hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue = 'Age', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'Age', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Marital_Status', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: >

# %%
df.groupby('City_Category')['Purchase'].sum().plot(kind = 'pie', autopct = "%0.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind = 'pie', autopct = "%0.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### Occupation and Products Analysis

# %% [markdown]
# Analyze how occupation influences purchasing behavior and which product categories are most popular among different occupations.

# %%
sns.countplot(x = df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years").size()
# Out:
# Stay_In_Current_City_Years
# 0      72725
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# dtype: int64

# %%
df.groupby("Stay_In_Current_City_Years").size().plot(kind='pie', autopct="%.1f")
# Out:
# <Axes: >

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue = 'Age',data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %% [markdown]
# Occupation

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x = 'Occupation', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').nunique()
# Out:
#             User_ID  Product_ID  Gender  Age  City_Category  \
# Occupation
# 0               688        3243       2    7              3
# 1               517        3020       2    7              3
# 2               256        2892       2    7              3
# 3               170        2657       2    6              3
# 4               740        3174       2    6              3
# 5               111        2344       2    6              3
# 6               228        2724       2    6              3
# 7               669        3070       2    7              3
# 8                17        1026       2    7              3
# 9                88        1820       2    6              3
# 10              192        2110       2    5              3
# 11              128        2235       2    7              3
# 12              376        2664       2    7              3
# 13              140        1946       2    5              3
# ...

# %%
df.groupby('Occupation')['Product_ID'].nunique()
# Out:
# Occupation
# 0     3243
# 1     3020
# 2     2892
# 3     2657
# 4     3174
# 5     2344
# 6     2724
# 7     3070
# 8     1026
# 9     1820
# 10    2110
# 11    2235
# 12    2664
# 13    1946
# 14    2680
# 15    2168
# 16    2863
# 17    2831
# 18    2047
# 19    2303
# 20    3147
# Name: Product_ID, dtype: int64

# %%
df.groupby('Occupation')['Product_ID'].nunique().sort_values()
# Out:
# Occupation
# 8     1026
# 9     1820
# 13    1946
# 18    2047
# 10    2110
# 15    2168
# 11    2235
# 19    2303
# 5     2344
# 3     2657
# 12    2664
# 14    2680
# 6     2724
# 17    2831
# 16    2863
# 2     2892
# 1     3020
# 7     3070
# 20    3147
# 4     3174
# 0     3243
# Name: Product_ID, dtype: int64

# %%
df.groupby('Occupation')['Product_ID'].nunique().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].sum().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
# people spend more money on these products
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
# most selling
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
# most expensive
df.groupby('Product_ID')['Purchase'].mean().nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# ### Combining Gender & Marital Status

# %% [markdown]
# investigate the combined effects of gender and marital status on purchasing behavior.

# %%
# creating another column in the dataset, which combine four different into one

l = []
for i in range(len(df)):
    l.append(df['Gender'][i]+"_"+str(df['Marital_Status'][i]))
df["Marital_gender"] = l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   Marital_gender
# 0            F_0
# 1            F_0
# 2            F_0
# 3            F_0
# 4            M_0

# %%
df["Marital_gender"]
# Out:
# 0         F_0
# 1         F_0
# 2         F_0
# 3         F_0
# 4         M_0
#          ...
# 537572    M_0
# 537573    M_0
# 537574    M_0
# 537575    M_0
# 537576    M_0
# Name: Marital_gender, Length: 537577, dtype: object

# %%
sns.countplot(x = df['Marital_gender'])
# Out:
# <Axes: xlabel='Marital_gender', ylabel='count'>

# %%
sns.countplot(x = df['Age'], hue = df['Marital_gender'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = df['Product_Category_1'], hue = df['Marital_gender'])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = df['Stay_In_Current_City_Years'], hue = df['Marital_gender'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'], hue = df['Marital_gender'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# ### Conclusion
#
# RESULT : unmarried males spends more in this dataset.
#
# This project helps to understand the purchasing behavior of Black Friday shoppers, provides insights into the influence of demographic factors like gender, age, marital status, and occupation on buying patterns. By using the Black Friday sales dataset, we walk through the process of cleaning the data, analyzing individual columns, and combining multiple features to uncover hidden patterns.
